# %% [markdown]
# lets start first with pie charts: Before we understand what a stack plot is, let’s visualize some simple data
#
# Imagine you surveyed how a group of students spends their after-school time:

# %%
import matplotlib.pyplot as plt

activities = ['Studying', 'Playing', 'Watching TV', 'Sleeping']
time_spent = [3, 2, 2, 5]  # hours in a day

colors = ['skyblue', 'lightgreen', 'gold', 'lightcoral']

plt.figure(figsize=(6,6))# size of piechart in inches
plt.pie(time_spent, labels=activities, colors=colors, autopct='%1.1f%%', startangle=90)
plt.title("After School Activities")
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# Interpretation:
# Studying: 3 hours
# Playing: 2 hours
# Watching TV: 2 hours
# Sleeping: 5 hours
# This pie chart shows how a single student spends time in one day.

# %% [markdown]
# But if want to survey multiple days and want to check how each activity change in period of time then stack plot is used
# A Stack Plot is a type of area chart that helps visualize multiple quantities over time, stacked on top of each other. It's especially useful to see how individual parts contribute to a whole over time.

# %%
import matplotlib.pyplot as plt

days = [1, 2, 3, 4, 5, 6, 7]  # Days of the week
studying = [3, 4, 3, 5, 4, 3, 4]
playing = [2, 2, 1, 1, 2, 3, 2]
watching_tv = [2, 1, 2, 2, 1, 1, 1]
sleeping = [5, 5, 6, 5, 6, 5, 5]

labels = ['Studying', 'Playing', 'Watching TV', 'Sleeping']
colors = ['skyblue', 'lightgreen', 'gold', 'lightcoral']

plt.figure(figsize=(6,6))
plt.stackplot(days, studying, playing, watching_tv, sleeping,
              labels=labels, colors=colors, alpha=0.8)# Transparency level 0 to 1

plt.legend(loc='upper left')  #loc is used for Location of the legend
plt.title('Weekly Activity Tracker')
plt.xlabel('Day')
plt.ylabel('Hours')# more than 1 y values like playing, studing, sleeping, TV
plt.grid(True)
plt.show()

# %%
Use stack plots to see how data changes over time while still showing parts of a whole.
Stack plots are a great way to tell a story over time.

# %%
#problem 1: Website Traffic Over Months: Create a stack plot showing traffic sources over a 6-month period.
import matplotlib.pyplot as plt
Months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun"]
Organic_Traffic = [1200, 1500, 1800, 1700, 1600, 2000]
Direct_Traffic = [800, 900, 1100, 1000, 950, 1200]
Referral_Traffic = [300, 350, 400, 380, 370, 450]
labels = ['Organic_Traffic','Direct_Traffic', 'Referral_Traffic']
colors = ['lightgreen', 'gold', 'red']
plt.stackplot(Months, Organic_Traffic, Direct_Traffic, Referral_Traffic, labels=labels,
              colors=colors, alpha=0.8)
plt.legend()
plt.xlabel("Months")
plt.ylabel("Traffic")
plt.title("Website Traffic Over Months")
# Out:
# Text(0.5, 1.0, 'Website Traffic Over Months')

# %%
#problem 2: Company Revenue by Product Line: Create a stack plot showing revenue for three product lines over 5 years.
#Data
Years = [2018, 2019, 2020, 2021, 2022]
ProductA = [20, 25, 30, 35, 40]
ProductB = [15, 18, 20, 22, 25]
ProductC = [10, 12, 15, 17, 20]
labels = ['Product A', 'Product B', 'Product C']
colors=['red', 'orange', 'pink']
plt.stackplot(Years, ProductA, ProductB, ProductC, labels=labels, colors=colors, alpha=0.8)
plt.xlabel('Years')
plt.ylabel('Product Revenue')
plt.title("Company Revenue by Product Line (2018–2022)")
plt.legend()

# %%
#problem 3: Energy Consumption by Source Create a stack plot showing annual energy consumption from different sources.
#Show all values in terawatt-hours (TWh).
Years = [2015, 2016, 2017, 2018, 2019]
Coal = [50, 48, 47, 45, 44]
Natural_Gas = [30, 32, 34, 35, 37]
Renewables = [10, 12, 14, 15, 16]
Nuclear = [10, 8, 5, 5, 3]
colors = ['black', 'grey', 'skyblue', 'red']
labels=['Coal', 'Natural Gas', 'Renewables', 'Nuclear']
plt.stackplot(Years, Coal, Natural_Gas, Renewables, Nuclear, colors=colors, labels=labels, alpha=0.8)
plt.xlabel("Years")
plt.ylabel("Energy Consumption (Twh)")
plt.title("Global Energy Consumption by Source")
plt.legend()

# %%
#problem 4: Students Enrolled in Subjects Create a stack plot showing the number of students enrolled in different subjects over 4 semesters.
Semesters = ["Sem 1", "Sem 2", "Sem 3", "Sem 4"]
Math = [50, 55, 60, 65]
Science = [40, 42, 45, 50]
English = [35, 38, 40, 43]
colors =['grey', 'orange', 'red']
labels=['Math', 'Science', 'English']
plt.stackplot(Semesters, Math, Science, English, colors=colors, labels=labels, alpha=0.8)
plt.xlabel("Semesters")
plt.ylabel("Students Enrolled")
plt.title("Student Enrollment in Subjects Over Semesters")
plt.legend()
plt.grid(True)

# %%
#problem 5: Daily Calorie Intake by Meal:- Create a stack plot showing the calorie distribution from meals over 7 days.
#Use three distinct colors for breakfast, lunch, and dinner.
Days = ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]
Breakfast = [400, 420, 390, 410, 430, 450, 460]
Lunch = [600, 650, 620, 630, 640, 660, 670]
Dinner = [500, 520, 510, 530, 540, 550, 560]
colors=['pink', 'orange', 'lightblue']
labels=['Breakfast', 'Lunch', 'Dinner']
plt.stackplot(Days, Breakfast, Lunch, Dinner, colors=colors, labels=labels, alpha=0.8)
plt.xlabel("Days")
plt.ylabel("Calories Intake")
plt.title("Daily Calorie Intake by Meal")
plt.legend()

# %% [markdown]
# Assignment: Try making a stackplot with your own weekly schedule!

# %%
import matplotlib.pyplot as plt
# Days of the week
days = ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]
# Hours spent on activities
sleep = [8, 7, 8, 7, 8, 9, 9]
study = [5, 6, 5, 6, 4, 2, 0]
exercise = [1, 1, 1, 1, 1, 2, 2]
leisure = [4, 3, 4, 3, 5, 6, 7]
other = [6, 7, 6, 7, 6, 5, 6]  # eating, chores, etc.
colors=['red', 'orange', 'pink', 'blue', 'purple']
labels=['Sleep', 'Study', 'Exercise', 'Leisure', 'Others']
plt.figure(figsize=(6, 6))
plt.stackplot(days, sleep, study, exercise, leisure, other, colors=colors, labels=labels, alpha=0.8)
plt.xlabel("Days")
plt.ylabel("Activities")
plt.title("Hours Spend on activities per day")
plt.legend(loc='upper left')
plt.grid(True)
