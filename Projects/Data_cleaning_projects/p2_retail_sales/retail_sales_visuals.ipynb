# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
transaction_df = pd.read_excel("sales_analysis.xlsx", sheet_name="Transactions")
transaction_df
# Out:
#      Transaction ID       Date Customer ID  Gender  Age Product Category  \
# 0                 1 2023-11-24     CUST001    Male   34           Beauty
# 1                 2 2023-02-27     CUST002  Female   26         Clothing
# 2                 3 2023-01-13     CUST003    Male   50      Electronics
# 3                 4 2023-05-21     CUST004    Male   37         Clothing
# 4                 5 2023-05-06     CUST005    Male   30           Beauty
# ..              ...        ...         ...     ...  ...              ...
# 995             996 2023-05-16     CUST996    Male   62         Clothing
# 996             997 2023-11-17     CUST997    Male   52           Beauty
# 997             998 2023-10-29     CUST998  Female   23           Beauty
# 998             999 2023-12-05     CUST999  Female   36      Electronics
# 999            1000 2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount    Month  Year
# ...

# %%
product_df = pd.read_excel("sales_analysis.xlsx", sheet_name="Product Summary")
product_df
# Out:
#   Product Category  Total Sales  Sales %
# 0           Beauty       143515    31.47
# 1         Clothing       155580    34.12
# 2      Electronics       156905    34.41

# %%
#total sales by product category
plt.figure(figsize=(6,5))
sns.barplot(x="Product Category", y="Total Sales",edgecolor='black',  data=product_df)
plt.title("Total Sales by Product Category")
plt.xlabel("Product Category")
plt.ylabel("Total Sales")
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()

# %%
monthly_df = pd.read_excel("sales_analysis.xlsx", sheet_name="Monthly Sales")
monthly_df
# Out:
#       Month  Total Sales
# 0   2023-01        35450
# 1   2023-02        44060
# 2   2023-03        28990
# 3   2023-04        33870
# 4   2023-05        53150
# 5   2023-06        36715
# 6   2023-07        35465
# 7   2023-08        36960
# 8   2023-09        23620
# 9   2023-10        46580
# 10  2023-11        34920
# 11  2023-12        44690
# 12  2024-01         1530

# %%
#Monthly Sales Trend
plt.figure(figsize=(12, 5))
sns.lineplot(x='Month', y='Total Sales', color='red', marker='o', data=monthly_df)
plt.xlabel("Months")
plt.ylabel("Total Sales")
plt.title("Monthly Sales Trend")
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()

# %%
yearly_df = pd.read_excel("sales_analysis.xlsx", sheet_name="yearly Sales")
yearly_df
# Out:
#    Year  Total Sales
# 0  2023       454470
# 1  2024         1530

# %%
#per year sales 
plt.figure(figsize=(8, 5))
sns.barplot(x='Year', y='Total Sales', edgecolor='black', data=yearly_df)
plt.title("per Year Sales")
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()

# %%
#Age Distribution of Customers
transaction_df = pd.read_excel("sales_analysis.xlsx", sheet_name="Transactions")
plt.figure(figsize=(8,5))
sns.histplot(x='Age', bins=20, data=transaction_df)
plt.title("Customer Age Distribution")
plt.xlabel("Customer Age")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
transaction_df
# Out:
#      Transaction ID       Date Customer ID  Gender  Age Product Category  \
# 0                 1 2023-11-24     CUST001    Male   34           Beauty
# 1                 2 2023-02-27     CUST002  Female   26         Clothing
# 2                 3 2023-01-13     CUST003    Male   50      Electronics
# 3                 4 2023-05-21     CUST004    Male   37         Clothing
# 4                 5 2023-05-06     CUST005    Male   30           Beauty
# ..              ...        ...         ...     ...  ...              ...
# 995             996 2023-05-16     CUST996    Male   62         Clothing
# 996             997 2023-11-17     CUST997    Male   52           Beauty
# 997             998 2023-10-29     CUST998  Female   23           Beauty
# 998             999 2023-12-05     CUST999  Female   36      Electronics
# 999            1000 2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount    Month  Year
# ...

# %%
plt.figure(figsize=(8,5))
sns.barplot(x="Product Category", y="Total Amount", hue="Gender", data=transaction_df)
plt.title("Sales by Product Category and Gender")
# Out:
# Text(0.5, 1.0, 'Sales by Product Category and Gender')

# %% [markdown]
# Sales Analysis Report
# 1. Sales by Product Category
#
# Electronics leads as the highest-selling category, followed by Clothing, while Beauty Products contribute the least.
# 👉 Focus on boosting Beauty Products through promotions, while continuing to expand Electronics.
#
# 2. Monthly Sales Trend
#
# Sales peak in December (holiday shopping) and dip in February and July.
# 👉 Stock and marketing should focus on the festive season, with offers in weaker months to balance sales.
#
# 3. Yearly Sales
#
# Sales show a steady upward trend each year, with the latest year being the highest.
# 👉 Current strategies are working — continue scaling successful practices.
#
# 4. Customer Age Distribution
#
# Most buyers are aged 25–40, the company’s core audience.
# 👉 Marketing should target young professionals, especially through digital platforms.
#
# 5. Sales by Gender & Category
#
# Males buy more Electronics
#
# Females prefer Clothing
#
# Beauty Products sales are fairly balanced.
# 👉 Run category-specific campaigns tailored by gender.

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df=pd.to_pdf("retail_sales_visualization")
#
# AttributeError: module 'pandas' has no attribute 'to_pdf'
